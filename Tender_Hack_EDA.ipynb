# %% [markdown]
# ## <font color='magenta'>{</font>Tender Hack<font color='magenta'>}</font> Екатеринбург
# # <p style='text-align: center;'><font color='black'>СОЗДАЙТЕ РЕКОМЕНДАТЕЛЬНЫЙ СЕРВИС ДЛЯ ЗАКУПОК ТОВАРОВ</font></p>

# %% [markdown]
# ## <font color='#00b43f'>ЦЕЛЬ И ЗАДАЧИ:</font>
#
# ### В рамках хакатона участникам предстоит реализовать задачи:
#
# - Проанализировать бизнес-процесс закупки товара заказчиком (как происходит выбор, какие блоки рекомендаций нужны, на каких страницах и где их можно отображать)
# - Выявить метрики эффективности этого процесса и их триггеры роста
# - Реализовать логику нахождения товаров, которые подходят к блоку "Вместе с этим покупают" в зависимости от сегмента и иных критериев с учетом исторических данных. Протестировать работу системы
# - Определить возможности по масштабированию решения и последующим его доработкам
# - Презентовать проект

# %%
# Возмём необходимые библиотеки
import pandas as pd 
import numpy as np 
import json 
Tender_Hack_Ekb = pd.read_excel('DataSet_EKB_200000.xlsx') 
# Посмотрим как выглядят данные:
Tender_Hack_Ekb.head()
# Out:
#    Идентификатор СТЕ                                   Наименование СТЕ  \
# 0           20528973  Светодиодная лента 2835, ULTRA, 12 Вольт, 60 l...
# 1           34860341  Светодиодный светильник Geniled ЛПО  1200?180?...
# 2           34172198  Елка пристенно-угловая Графская премиум 210 см...
# 3            1318014  Картридж HP CE278A/Canon 728 LJ P1560/1566/160...
# 4            1251411  Штамп самонаборный Pr.C20/3-Set 38х14 (аналог ...
#
#                                            Категория Описание  \
# 0                                 Лампы светодиодные      NaN
# 1                    Настенно-потолочные светильники      NaN
# 2                     Предметы внутреннего интерьера      NaN
# 3  Расходные материалы и комплектующие для лазерн...      NaN
# 4                                           Штемпели      NaN
#
#                                   Характеристики СТЕ  \
# 0  [{"Name":"Цвет свечения","Id":-506425117,"Valu...
# 1  [{"Name":"Вид климатического исполнения","Id":...
# 2  [{"Name":"Цвет","Id":340085190,"Value":"Зелены...
# 3  [{"Name":"Тип расходника","Id":317455168,"Valu...
# 4  [{"Name":"Наличие рамки","Id":366100137,"Value...
#
#                                     Регионы поставки  \
# 0                                [{"Name":"Москва"}]
# 1        [{"Name":"Свердловская"},{"Name":"Москва"}]
# 2         [{"Name":"Москва"},{"Name":"Все регионы"}]
# 3          [{"Name":"Москва"},{"Name":"Московская"}]
# 4  [{"Name":"Белгородская"},{"Name":"Марий Эл"},{...
#
#    Кол-во заключенных контрактов  \
# 0                            NaN
# 1                            1.0
# 2                            NaN
# 3                            9.0
# 4                           71.0
#
#                                           Поставщики Страна происхождения  \
# 0  [{"SupplierId":2310783,"Name":"ООО \"ЛЮМЕНВАТТ...                  NaN
# 1  [{"SupplierId":1559525,"Name":"Общество с огра...               РОССИЯ
# 2  [{"SupplierId":1348988,"Name":"ИП Чепало Оксан...                  NaN
# 3  [{"SupplierId":1111141,"Name":"Общество с огра...                  NaN
# 4  [{"SupplierId":1100019,"Name":"ООО \"ЦТО\"","I...              АВСТРИЯ
#
#                        Другая продукция в контрактах  Просмотры  \
# 0                                                NaN          1
# 1                                                NaN         41
# 2                                                NaN          5
# 3  [{"OtherSkuId":1398583,"OtherSkuName":"013R006...          6
# 4  [{"OtherSkuId":1171023,"OtherSkuName":"Berling...         72
#
#    Идентификатор КПГЗ           Код КПГЗ  \
# 0          12106442.0     01.10.05.02.04
# 1          12114082.0  01.10.05.03.01.05
# 2             68093.0           01.20.08
# 3          12105204.0     01.13.13.01.01
# 4          12120460.0        01.15.06.07
#
#                                               Модель  \
# 0                                          2835ULTRA
# 1                    ЛПО 1200?180?40 40Вт 5000К Опал
# 2    Елка пристенно-угловая Графская премиум 210 см.
# 3                                       SF-CE278(2K)
# 4  Штамп самонаборный пласт. 3стр. Pr.C20/3-Set 3...
#
#                                                 Цена
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  [{"Cost":454.67000},{"Cost":620.00000},{"Cost"...

# %%
# Посмотрим информацию по полученным данным: 
Tender_Hack_Ekb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Идентификатор СТЕ              200000 non-null  int64
#  1   Наименование СТЕ               200000 non-null  object
#  2   Категория                      200000 non-null  object
#  3   Описание                       26165 non-null   object
#  4   Характеристики СТЕ             199975 non-null  object
#  5   Регионы поставки               200000 non-null  object
#  6   Кол-во заключенных контрактов  161214 non-null  float64
#  7   Поставщики                     200000 non-null  object
#  8   Страна происхождения           70819 non-null   object
#  9   Другая продукция в контрактах  151895 non-null  object
#  10  Просмотры                      200000 non-null  int64
#  11  Идентификатор КПГЗ             199976 non-null  float64
#  12  Код КПГЗ                       199976 non-null  object
#  13  Модель                         145815 non-null  object
#  14  Цена                           96763 non-null   object
# dtypes: float64(2), int64(2), object(11)
# memory usage: 22.9+ MB

# %% [markdown]
# Из полученных даных видим, что есть много пропусков, цена указана только в **48%** заказах

# %%
# На основе полученного DataFrame создадим новый с корректными данными для дальнейшей работы
Tender_data = Tender_Hack_Ekb[['Идентификатор СТЕ','Наименование СТЕ','Категория','Описание','Кол-во заключенных контрактов','Страна происхождения','Просмотры','Идентификатор КПГЗ','Код КПГЗ','Модель']]

# %%
# Извлечём из JSON формата данные
tender_har = [np.nan for _ in range(len(Tender_Hack_Ekb['Характеристики СТЕ']))] 
for i,row in enumerate(Tender_Hack_Ekb['Характеристики СТЕ']): 
    if pd.isna(row): 
        continue 
    else: 
        tender_har[i] = json.loads('[' + row[row.find('{'):row.rfind('}') + 1] + ']') 
Tender_data.insert(10, 'Характеристики СТЕ', tender_har, True)

# %%
# Извлечём из JSON формата данные
tender_region = [np.nan for _ in range(len(Tender_Hack_Ekb['Регионы поставки']))] 
for i,row in enumerate(Tender_Hack_Ekb['Регионы поставки']): 
    if pd.isna(row): 
        continue 
    else: 
        tender_region[i] = json.loads(row) 
Tender_data.insert(11, 'Регионы поставки', tender_region, True)

# %%
# Извлечём из JSON формата данные
tender_post = [np.nan for _ in range(len(Tender_Hack_Ekb['Поставщики']))] 
for i,row in enumerate(Tender_Hack_Ekb['Поставщики']): 
    if pd.isna(row): 
        continue 
    else: 
        tender_post[i] = json.loads(row) 
Tender_data.insert(12, 'Поставщики', tender_post, True)

# %%
# Извлечём из JSON формата данные 
tender_dr = [np.nan for _ in range(len(Tender_Hack_Ekb['Другая продукция в контрактах']))] 
for i,row in enumerate(Tender_Hack_Ekb['Другая продукция в контрактах']): 
    if pd.isna(row): 
        continue 
    else: 
        tender_dr[i] = json.loads('[' + row[row.find('{'):row.rfind('}') + 1] + ']') 
Tender_data.insert(13, 'Другая продукция в контрактах', tender_dr, True)

# %%
# Извлечём из JSON формата данные и добавим столбец с медианной ценой (необходима будет для дальнейшего анализа)
tender_price = [np.nan for _ in range(len(Tender_Hack_Ekb['Цена']))] 
tender_cost = [np.nan for _ in range(len(Tender_Hack_Ekb['Цена']))] 
for i,row in enumerate(Tender_Hack_Ekb['Цена']): 
    if pd.isna(row): 
        continue 
    else: 
        tender_price[i] = json.loads(row) 
        Sum_cost_list = [] 
        for cost in tender_price[i]: 
            Sum_cost_list.append(cost['Cost']) 
        tender_cost[i] = np.median(Sum_cost_list) 
Tender_data.insert(14, 'Цена', tender_price, True) 
Tender_data.insert(15, 'Цена медианная', tender_cost, True)

# %%
# Выведем на экран, посмотрим, что получилось: 
Tender_data
# Out:
#         Идентификатор СТЕ                                   Наименование СТЕ  \
# 0                20528973  Светодиодная лента 2835, ULTRA, 12 Вольт, 60 l...
# 1                34860341  Светодиодный светильник Geniled ЛПО  1200?180?...
# 2                34172198  Елка пристенно-угловая Графская премиум 210 см...
# 3                 1318014  Картридж HP CE278A/Canon 728 LJ P1560/1566/160...
# 4                 1251411  Штамп самонаборный Pr.C20/3-Set 38х14 (аналог ...
# ...                   ...                                                ...
# 199995           19731803                         Тонер оригинальный TNP-48C
# 199996           19352524  Картридж GP-Q2612A/703 для принтеров HP LJ 101...
# 199997           19360334  Картридж GP-CE400X для принтеров HP Color Lase...
# 199998           19361214  Картридж GP-CE401A для принтеров HP Color Lase...
# 199999           19374529                        Совместимый картридж TARGET
#
#                                                 Категория Описание  \
# 0                                      Лампы светодиодные      NaN
# 1                         Настенно-потолочные светильники      NaN
# 2                          Предметы внутреннего интерьера      NaN
# 3       Расходные материалы и комплектующие для лазерн...      NaN
# 4                                                Штемпели      NaN
# ...                                                   ...      ...
# 199995  Расходные материалы и комплектующие для лазерн...      NaN
# 199996  Расходные материалы и комплектующие для лазерн...      NaN
# 199997  Расходные материалы и комплектующие для лазерн...      NaN
# 199998  Расходные материалы и комплектующие для лазерн...      NaN
# 199999  Расходные материалы и комплектующие для лазерн...      NaN
#
#         Кол-во заключенных контрактов Страна происхождения  Просмотры  \
# 0                                 NaN                  NaN          1
# 1                                 1.0               РОССИЯ         41
# 2                                 NaN                  NaN          5
# 3                                 9.0                  NaN          6
# 4                                71.0              АВСТРИЯ         72
# ...                               ...                  ...        ...
# 199995                            2.0   ЧЕШСКАЯ РЕСПУБЛИКА          0
# 199996                            2.0   ЧЕШСКАЯ РЕСПУБЛИКА          3
# 199997                            2.0   ЧЕШСКАЯ РЕСПУБЛИКА          8
# 199998                            2.0   ЧЕШСКАЯ РЕСПУБЛИКА          5
# 199999                            2.0   ЧЕШСКАЯ РЕСПУБЛИКА          0
#
#         Идентификатор КПГЗ           Код КПГЗ  \
# 0               12106442.0     01.10.05.02.04
# 1               12114082.0  01.10.05.03.01.05
# 2                  68093.0           01.20.08
# 3               12105204.0     01.13.13.01.01
# 4               12120460.0        01.15.06.07
# ...                    ...                ...
# 199995          12105204.0     01.13.13.01.01
# 199996          12105204.0     01.13.13.01.01
# 199997          12105204.0     01.13.13.01.01
# 199998          12105204.0     01.13.13.01.01
# 199999          12105204.0     01.13.13.01.01
#
#                                                    Модель  \
# 0                                               2835ULTRA
# 1                         ЛПО 1200?180?40 40Вт 5000К Опал
# 2         Елка пристенно-угловая Графская премиум 210 см.
# 3                                            SF-CE278(2K)
# 4       Штамп самонаборный пласт. 3стр. Pr.C20/3-Set 3...
# ...                                                   ...
# 199995                                            TNP-48C
# 199996                                             Q2612A
# 199997                                             CE400X
# 199998                                             CE401A
# 199999                                         TR-TN-2175
#
#                                        Характеристики СТЕ  \
# 0       [{'Name': 'Цвет свечения', 'Id': -506425117, '...
# 1       [{'Name': 'Вид климатического исполнения', 'Id...
# 2       [{'Name': 'Цвет', 'Id': 340085190, 'Value': 'З...
# 3       [{'Name': 'Тип расходника', 'Id': 317455168, '...
# 4       [{'Name': 'Наличие рамки', 'Id': 366100137, 'V...
# ...                                                   ...
# 199995  [{'Name': 'Модель аппарата', 'Id': -551791201,...
# 199996  [{'Name': 'Цвет', 'Id': -569744851, 'Value': '...
# 199997  [{'Name': 'Цвет', 'Id': -569753984, 'Value': '...
# 199998  [{'Name': 'Совместимые модели принтеров', 'Id'...
# 199999  [{'Name': 'Цвет', 'Id': -568748255, 'Value': '...
#
#                                          Регионы поставки  \
# 0                                    [{'Name': 'Москва'}]
# 1          [{'Name': 'Свердловская'}, {'Name': 'Москва'}]
# 2           [{'Name': 'Москва'}, {'Name': 'Все регионы'}]
# 3            [{'Name': 'Москва'}, {'Name': 'Московская'}]
# 4       [{'Name': 'Белгородская'}, {'Name': 'Марий Эл'...
# ...                                                   ...
# 199995                               [{'Name': 'Москва'}]
# 199996       [{'Name': 'Москва'}, {'Name': 'Московская'}]
# 199997                               [{'Name': 'Москва'}]
# 199998                               [{'Name': 'Москва'}]
# 199999                               [{'Name': 'Москва'}]
#
#                                                Поставщики  \
# 0       [{'SupplierId': 2310783, 'Name': 'ООО "ЛЮМЕНВА...
# 1       [{'SupplierId': 1559525, 'Name': 'Общество с о...
# 2       [{'SupplierId': 1348988, 'Name': 'ИП Чепало Ок...
# 3       [{'SupplierId': 1111141, 'Name': 'Общество с о...
# 4       [{'SupplierId': 1100019, 'Name': 'ООО "ЦТО"', ...
# ...                                                   ...
# 199995  [{'SupplierId': 1101401, 'Name': 'ИП Великий Я...
# 199996  [{'SupplierId': 1102234, 'Name': 'Общество с о...
# 199997  [{'SupplierId': 1561169, 'Name': 'Общество с о...
# 199998  [{'SupplierId': 1561169, 'Name': 'Общество с о...
# 199999  [{'SupplierId': 1111396, 'Name': 'ООО "КАРТРИД...
#
#                             Другая продукция в контрактах  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3       [{'OtherSkuId': 1398583, 'OtherSkuName': '013R...
# 4       [{'OtherSkuId': 1171023, 'OtherSkuName': 'Berl...
# ...                                                   ...
# 199995  [{'OtherSkuId': 20919916, 'OtherSkuName': 'Кар...
# 199996  [{'OtherSkuId': 22976031, 'OtherSkuName': 'Вал...
# 199997  [{'OtherSkuId': 34579817, 'OtherSkuName': 'Бар...
# 199998  [{'OtherSkuId': 34579817, 'OtherSkuName': 'Бар...
# 199999  [{'OtherSkuId': 18933206, 'OtherSkuName': 'Кар...
#
#                                                      Цена  Цена медианная
# 0                                                     NaN             NaN
# 1                                                     NaN             NaN
# 2                                                     NaN             NaN
# 3                                                     NaN             NaN
# 4       [{'Cost': 454.67}, {'Cost': 620.0}, {'Cost': 6...           620.0
# ...                                                   ...             ...
# 199995                                                NaN             NaN
# 199996                                                NaN             NaN
# 199997                                 [{'Cost': 2450.0}]          2450.0
# 199998                                 [{'Cost': 2450.0}]          2450.0
# 199999                                                NaN             NaN
#
# [200000 rows x 16 columns]

# %%
# Сохраним DataFrame в формате xlsx
Tender_data[['Идентификатор СТЕ','Наименование СТЕ','Категория','Описание','Кол-во заключенных контрактов','Страна происхождения','Просмотры','Идентификатор КПГЗ','Код КПГЗ','Модель','Цена медианная']].to_excel("Tender_data_11_columns.xlsx")

# %%
# Отсортируем DataFrame по количеству заказов и количеству просмотров для дальнейшего выбора популярных товаров: 
Tender_data1 = Tender_data.sort_values(by=['Кол-во заключенных контрактов','Просмотры'], ascending=False).reset_index(drop=True) 
Tender_data1
# Out:
#         Идентификатор СТЕ                                   Наименование СТЕ  \
# 0                17491984  Фентанил р-р для в/в и в/м 50 мкг/мл 2 мл амп ...
# 1                17357675                 Сибазон р-р в/в в/м введ 5мг/мл №5
# 2                28145480  Бумага для офисной техники SvetoCopy (A4, марк...
# 3                17264617                  Промедол р-р д/ин 20мг/мл амп 1мл
# 4                17304105                    Морфин р-р д/ин 10мг/мл амп 1мл
# ...                   ...                                                ...
# 199995           34084556                        Трос буксировочный ТБ-1/5 м
# 199996           34103706  Заградительная сетка артикул:10030, ячейка 100...
# 199997           34172038  Средство жидкое для мытья поверхностей "Ника у...
# 199998           23470486                        КОСТЮМ «АНТЕЙ» с СОП, синий
# 199999           19971051       Автоподатчик с дуплексом в сборе JC97-03885A
#
#                                                 Категория      Описание  \
# 0                                          АНЕСТЕТИКИ,N01  Импорт ЕМИАС
# 1                              ПСИХОТРОПНЫЕ ПРЕПАРАТЫ,N05  Импорт ЕМИАС
# 2                        Бумага для офисной техники белая           NaN
# 3                                          АНЕСТЕТИКИ,N01  Импорт ЕМИАС
# 4                                         АНАЛЬГЕТИКИ,N02  Импорт ЕМИАС
# ...                                                   ...           ...
# 199995                              Прочие автоаксессуары           NaN
# 199996  Оборудование и инвентарь для футбола, мини-фут...           NaN
# 199997      Средства моющие для поверхностей в помещениях           NaN
# 199998  Одежда специальная для защиты от общих произво...           NaN
# 199999  Расходные материалы и комплектующие для лазерн...           NaN
#
#         Кол-во заключенных контрактов Страна происхождения  Просмотры  \
# 0                               884.0               РОССИЯ        190
# 1                               752.0               РОССИЯ        121
# 2                               624.0               РОССИЯ       4658
# 3                               567.0               РОССИЯ         73
# 4                               533.0               РОССИЯ        156
# ...                               ...                  ...        ...
# 199995                            NaN                  NaN          0
# 199996                            NaN                  NaN          0
# 199997                            NaN                  NaN          0
# 199998                            NaN                  NaN          0
# 199999                            NaN   ЧЕШСКАЯ РЕСПУБЛИКА          0
#
#         Идентификатор КПГЗ           Код КПГЗ  \
# 0               12106263.0     01.02.09.10.01
# 1               12106268.0     01.02.09.10.05
# 2               12119424.0  01.15.01.01.01.01
# 3               12106263.0     01.02.09.10.01
# 4               12106264.0     01.02.09.10.02
# ...                    ...                ...
# 199995          12124027.0     01.09.08.02.99
# 199996          12123059.0     01.08.01.13.99
# 199997          12114306.0     01.20.04.02.13
# 199998          12113841.0        01.19.10.05
# 199999          12105204.0     01.13.13.01.01
#
#                                                  Модель  \
# 0                                             амп N 5x2
# 1                                               амп 2мл
# 2                                               Classic
# 3                                                   NaN
# 4                                                  №5х2
# ...                                                 ...
# 199995                                      Петля-петля
# 199996                                            10030
# 199997  Ника универсальное с антибактериальным эффектом
# 199998                                          «АНТЕЙ»
# 199999                                      JC97-03885A
#
#                                        Характеристики СТЕ  \
# 0       [{'Name': 'Объем индивидуальной упаковки', 'Id...
# 1       [{'Name': 'Международное непатентованное назва...
# 2       [{'Name': 'Соответствует требованиям ГОСТ Р  5...
# 3       [{'Name': 'Объем индивидуальной упаковки', 'Id...
# 4       [{'Name': 'Количество во вторичной упаковке', ...
# ...                                                   ...
# 199995  [{'Name': 'Вид аксессуара', 'Id': 336554930, '...
# 199996  [{'Name': 'Материал нити', 'Id': 337668128, 'V...
# 199997  [{'Name': 'Вид напольного покрытия', 'Id': 339...
# 199998  [{'Name': 'Капюшон', 'Id': -297533354, 'Value'...
# 199999  [{'Name': 'Тип расходника', 'Id': -543018153, ...
#
#                                          Регионы поставки  \
# 0       [{'Name': 'Москва'}, {'Name': 'Пермский'}, {'N...
# 1       [{'Name': 'Москва'}, {'Name': 'Пермский'}, {'N...
# 2       [{'Name': 'Чечня'}, {'Name': 'Амурская'}, {'Na...
# 3              [{'Name': 'Москва'}, {'Name': 'Пермский'}]
# 4              [{'Name': 'Москва'}, {'Name': 'Пермский'}]
# ...                                                   ...
# 199995  [{'Name': 'Москва'}, {'Name': 'Московская'}, {...
# 199996  [{'Name': 'Москва'}, {'Name': 'Московская'}, {...
# 199997  [{'Name': 'Свердловская'}, {'Name': 'Москва'},...
# 199998  [{'Name': 'Москва'}, {'Name': 'Московская'}, {...
# 199999                               [{'Name': 'Москва'}]
#
#                                                Поставщики  \
# 0       [{'SupplierId': 1100362, 'Name': 'Государствен...
# 1       [{'SupplierId': 1100092, 'Name': 'АО "Парма Ме...
# 2       [{'SupplierId': 1100019, 'Name': 'ООО "ЦТО"', ...
# 3       [{'SupplierId': 1100362, 'Name': 'Государствен...
# 4       [{'SupplierId': 1100362, 'Name': 'Государствен...
# ...                                                   ...
# 199995  [{'SupplierId': 1279922, 'Name': 'Общество с о...
# 199996  [{'SupplierId': 1789374, 'Name': 'Индивидуальн...
# 199997  [{'SupplierId': 1103258, 'Name': 'ООО "ОФИСМАГ...
# 199998  [{'SupplierId': 2310381, 'Name': 'ООО "ИВТЕНДЕ...
# 199999  [{'SupplierId': 1109724, 'Name': 'ООО "КРАФТВЭ...
#
#                             Другая продукция в контрактах  \
# 0       [{'OtherSkuId': 17416741, 'OtherSkuName': 'Алп...
# 1       [{'OtherSkuId': 17416741, 'OtherSkuName': 'Алп...
# 2       [{'OtherSkuId': 32250359, 'OtherSkuName': '"Er...
# 3       [{'OtherSkuId': 17416741, 'OtherSkuName': 'Алп...
# 4       [{'OtherSkuId': 17416741, 'OtherSkuName': 'Алп...
# ...                                                   ...
# 199995                                                NaN
# 199996  [{'OtherSkuId': 21810915, 'OtherSkuName': 'Бас...
# 199997                                                NaN
# 199998                                                NaN
# 199999  [{'OtherSkuId': 20221083, 'OtherSkuName': 'Дат...
#
#                                                      Цена  Цена медианная
# 0       [{'Cost': 183.26}, {'Cost': 209.0}, {'Cost': 2...         209.000
# 1                        [{'Cost': 60.5}, {'Cost': 74.5}]          67.500
# 2       [{'Cost': 128.52}, {'Cost': 183.04}, {'Cost': ...         232.010
# 3                     [{'Cost': 250.25}, {'Cost': 318.0}]         284.125
# 4                                       [{'Cost': 363.0}]         363.000
# ...                                                   ...             ...
# 199995                                                NaN             NaN
# 199996                                                NaN             NaN
# 199997                                  [{'Cost': 120.4}]         120.400
# 199998                                                NaN             NaN
# 199999                                [{'Cost': 12498.0}]       12498.000
#
# [200000 rows x 16 columns]

# %%
# Создадим DataFrame в котором будут содержаться идентификаторы товаров и количество заказов, где они встречались:
OtherSkyId = [np.nan for _ in range(len(Tender_data1['Идентификатор СТЕ']))] 
CountContract = [np.nan for _ in range(len(Tender_data1['Идентификатор СТЕ']))] 
Category = [np.nan for _ in range(len(Tender_data1['Идентификатор СТЕ']))]
from collections import defaultdict
item_to_sum = defaultdict(int)
def summing(x):
    print(x)
    item_to_sum[x['Идентификатор СТЕ']] += x['Кол-во заключенных контрактов']
    return True
td = Tender_data1.reset_index()
TD = td.groupby('Идентификатор СТЕ')['Кол-во заключенных контрактов'].sum().reset_index().sort_values(by=['Кол-во заключенных контрактов'], ascending=False) 
TD # Выведем на экран
# Out:
#         Идентификатор СТЕ  Кол-во заключенных контрактов
# 63243            17491984                          884.0
# 61398            17357675                          752.0
# 152066           28145480                          624.0
# 60180            17264617                          567.0
# 60703            17304105                          533.0
# ...                   ...                            ...
# 28899             1233162                            0.0
# 172766           34220011                            0.0
# 49926             1382289                            0.0
# 172768           34220018                            0.0
# 114511           21215047                            0.0
#
# [200000 rows x 2 columns]

# %% [markdown]
# Создадим DataFrame, в котором будет содержаться Код КПГЗ до 5 позиции (категория товаров) и идентификаторы новых товаров (**10%** от общего числа в категории):

# %%
Tender_data1['Код КПГЗ_4'] = Tender_data1['Код КПГЗ'].apply(lambda x: '.'.join(str(x).split('.')[:5]))
td1 = Tender_data1.groupby('Код КПГЗ_4')['Идентификатор СТЕ'].apply(lambda x: sorted(list(x),reverse=True)).reset_index() 
def new_10(x): 
    if len(x) > 10: 
        return x[:int(0.1*len(x))+1] 
    return x 
td1['Идентификатор СТЕ'] = td1['Идентификатор СТЕ'].apply(lambda x: new_10(x)) 
td1 = td1.rename(columns={'Идентификатор СТЕ':'Идентификаторы СТЕ'}) 
td1
# Out:
#           Код КПГЗ_4                                 Идентификаторы СТЕ
# 0     01.01.01.01.01                     [34858656, 34804127, 34645066]
# 1     01.01.01.01.02  [34846872, 34531976, 33985601, 24449486, 23834...
# 2     01.01.01.01.03  [28434892, 19338887, 18076417, 17780732, 1442855]
# 3     01.01.01.01.04                     [34991353, 34707970, 22166770]
# 4     01.01.01.01.05                     [34913762, 34529249, 34013987]
# ...              ...                                                ...
# 2462  01.26.01.02.02           [33779793, 33759003, 33186563, 24408781]
# 2463  01.26.02.04.02                                         [28143830]
# 2464        01.26.08                     [34242308, 28512774, 28512010]
# 2465        01.26.09                                         [26322899]
# 2466             nan                     [23446500, 23445519, 23444744]
#
# [2467 rows x 2 columns]

# %%
# Объединим DataFrames 
s = Tender_data1[['Идентификатор СТЕ','Код КПГЗ_4']] 
td3 = s.merge(td1, how='left', on='Код КПГЗ_4') 
td4 = TD.merge(td3, how='left', on='Идентификатор СТЕ') 
td4
# Out:
#         Идентификатор СТЕ  Кол-во заключенных контрактов      Код КПГЗ_4  \
# 0                17491984                          884.0  01.02.09.10.01
# 1                17357675                          752.0  01.02.09.10.05
# 2                28145480                          624.0  01.15.01.01.01
# 3                17264617                          567.0  01.02.09.10.01
# 4                17304105                          533.0  01.02.09.10.02
# ...                   ...                            ...             ...
# 199995            1233162                            0.0     01.01.07.07
# 199996           34220011                            0.0     01.19.10.06
# 199997            1382289                            0.0        01.15.09
# 199998           34220018                            0.0     01.19.10.06
# 199999           21215047                            0.0  01.20.09.01.99
#
#                                        Идентификаторы СТЕ
# 0       [34780820, 34649281, 34529285, 24307251, 23831...
# 1       [35032365, 33027172, 26323774, 23910042, 23909...
# 2       [34968711, 34934763, 34891023, 34881521, 34867...
# 3       [34780820, 34649281, 34529285, 24307251, 23831...
# 4       [34741030, 34737330, 34026520, 30538650, 26204...
# ...                                                   ...
# 199995  [28467460, 21575960, 21127592, 19287410, 18917...
# 199996  [34923653, 34923632, 34923330, 34814956, 34814...
# 199997  [35137419, 35022375, 35016476, 34976580, 34969...
# 199998  [34923653, 34923632, 34923330, 34814956, 34814...
# 199999  [35037387, 35031553, 34954520, 34918065, 34872...
#
# [200000 rows x 4 columns]

# %%
# Добавим в DataFrame столбец "Новизна" со значениями 1 - новый товар, 0 - не новый товар
td4['Новизна'] = td4.apply(lambda x: 1 if x['Идентификатор СТЕ'] in x['Идентификаторы СТЕ'] else 0, axis=1) 
# Удалим дубликаты товаров, если они есть
td4.drop_duplicates(subset=['Идентификатор СТЕ'])
# Out:
#         Идентификатор СТЕ  Кол-во заключенных контрактов      Код КПГЗ_4  \
# 0                17491984                          884.0  01.02.09.10.01
# 1                17357675                          752.0  01.02.09.10.05
# 2                28145480                          624.0  01.15.01.01.01
# 3                17264617                          567.0  01.02.09.10.01
# 4                17304105                          533.0  01.02.09.10.02
# ...                   ...                            ...             ...
# 199995            1233162                            0.0     01.01.07.07
# 199996           34220011                            0.0     01.19.10.06
# 199997            1382289                            0.0        01.15.09
# 199998           34220018                            0.0     01.19.10.06
# 199999           21215047                            0.0  01.20.09.01.99
#
#                                        Идентификаторы СТЕ  Новизна
# 0       [34780820, 34649281, 34529285, 24307251, 23831...        0
# 1       [35032365, 33027172, 26323774, 23910042, 23909...        0
# 2       [34968711, 34934763, 34891023, 34881521, 34867...        1
# 3       [34780820, 34649281, 34529285, 24307251, 23831...        0
# 4       [34741030, 34737330, 34026520, 30538650, 26204...        0
# ...                                                   ...      ...
# 199995  [28467460, 21575960, 21127592, 19287410, 18917...        0
# 199996  [34923653, 34923632, 34923330, 34814956, 34814...        0
# 199997  [35137419, 35022375, 35016476, 34976580, 34969...        0
# 199998  [34923653, 34923632, 34923330, 34814956, 34814...        0
# 199999  [35037387, 35031553, 34954520, 34918065, 34872...        0
#
# [200000 rows x 5 columns]

# %%
# Выберем необходимые данные
New_table = td4[['Идентификатор СТЕ','Кол-во заключенных контрактов','Код КПГЗ_4','Новизна']].\
merge(Tender_data1[['Идентификатор СТЕ','Страна происхождения','Просмотры']], how='left', on='Идентификатор СТЕ') 
New_table
# Out:
#         Идентификатор СТЕ  Кол-во заключенных контрактов      Код КПГЗ_4  \
# 0                17491984                          884.0  01.02.09.10.01
# 1                17357675                          752.0  01.02.09.10.05
# 2                28145480                          624.0  01.15.01.01.01
# 3                17264617                          567.0  01.02.09.10.01
# 4                17304105                          533.0  01.02.09.10.02
# ...                   ...                            ...             ...
# 199995            1233162                            0.0     01.01.07.07
# 199996           34220011                            0.0     01.19.10.06
# 199997            1382289                            0.0        01.15.09
# 199998           34220018                            0.0     01.19.10.06
# 199999           21215047                            0.0  01.20.09.01.99
#
#         Новизна Страна происхождения  Просмотры
# 0             0               РОССИЯ        190
# 1             0               РОССИЯ        121
# 2             1               РОССИЯ       4658
# 3             0               РОССИЯ         73
# 4             0               РОССИЯ        156
# ...         ...                  ...        ...
# 199995        0                  NaN          0
# 199996        0                  NaN          0
# 199997        0                  NaN          2
# 199998        0                  NaN          1
# 199999        0                  NaN          0
#
# [200000 rows x 6 columns]

# %%
# Сохраним DataFrame в формате csv для дальнейшей работы с ним в ML model
New_table.to_csv('New_table.csv')
