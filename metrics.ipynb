# %%
import os
import json
import pandas as pd

from tqdm import tqdm
tqdm.pandas()

from typing import *
from matplotlib import pyplot as plt
import plotly.express as px

if os.getcwd().endswith('notebooks'):
    os.chdir('..')

# %%
raw_data_filename = 'DataSet_EKB_200000.xlsx'

df = pd.read_excel(
    raw_data_filename,
    engine='openpyxl',
)

# df = df.head(10000)

df['Другая продукция в контрактах'] = (
    df['Другая продукция в контрактах']
    .progress_apply(
        lambda x: (
            x.rsplit('{', maxsplit=1)[0][:-1] + ']'
            if not x.endswith(']') else x
        )
        if not pd.isnull(x) else None
    )
)
# Out:
# 100%|██████████| 200000/200000 [00:01<00:00, 193371.98it/s]

# %%
def parse_json(s: str) -> list:
    if not pd.notnull(s):
        result = None
    else:
        try:
            result = json.loads(s)
        except json.JSONDecodeError:
            return None

    return result


def prepare_data(df: pd.DataFrame) -> Tuple[pd.DataFrame, pd.DataFrame]:
    df['Другая продукция в контрактах'] = df['Другая продукция в контрактах'].progress_apply(parse_json)
    df['cat'] = df['Код КПГЗ'].apply(lambda x: '.'.join(str(x).split('.')[:4]))

    df_train = df.tail(180000)
    df_test = df.head(20000)

    df_test['Другая продукция в контрактах'] = (
        df_test['Другая продукция в контрактах']
        .apply(lambda l: [str(x['OtherSkuId']) for x in l] if l is not None else [])
    )

    return df_train, df_test

# %%
def calc_recall(
    y_true: List[List[str]],
    y_pred: List[List[str]],
) -> float:
    n_relevant = 0
    n_total = 0
    for true, pred in zip(y_true, y_pred):
        n_relevant += len([item for item in true if item in pred])
        n_total += len(true)

    recall = n_relevant / n_total

    return recall


def calc_precision(
    y_true: List[List[str]],
    y_pred: List[List[str]],
) -> float:
    n_found = 0
    n_total = len(y_true)
    for true, pred in zip(y_true, y_pred):
        n_found += any([item for item in pred if item in true])

    precision = n_found / n_total

    return precision


def metrics(
    y_true: List[List[str]],
    y_pred: List[List[str]],
) -> Tuple[float, float]:
    recall = calc_recall(y_true, y_pred)
    precision = calc_precision(y_true, y_pred)
    return recall, precision

# %%
def get_pred_from_baseline(df_train: pd.DataFrame, df_test: pd.DataFrame) -> List[List[str]]:
    df_train['Кол-во заключенных контрактов'] = df_train['Кол-во заключенных контрактов'].fillna(0)
    df_train['tuple'] = df_train.apply(lambda row: (row['Идентификатор СТЕ'], row['Кол-во заключенных контрактов']), axis=1)
    df_cat = (
        df_train
        .groupby('cat')['tuple']
        .apply(lambda group: [x[0] for x in sorted(list(group), key=lambda x: -x[1])][:20])
    )

    y_pred_baseline = (
        df_test
        .join(
            df_cat,
            how='left',
            on='cat'
        )
        ['tuple']
        .apply(lambda d: d if isinstance(d, list) else [])
        .apply(lambda l: [str(x) for x in l][:20])
        .values
    )

    return y_pred_baseline


def get_pred_from_model(df_test: pd.DataFrame, df_pred: pd.DataFrame) -> List[List[str]]:
    df_pred['Сопутствующие товары'] = df_pred['Сопутствующие товары'].apply(lambda x: x[1:-1].split())

    df_pred_ = (
        df_test
        .set_index('Идентификатор СТЕ')
        .join(
            df_pred
            .set_index('Идентификатор СТЕ'),
            how='left'
        )
    )
    df_pred_['Сопутствующие товары'] = df_pred_['Сопутствующие товары'].apply(lambda d: d if isinstance(d, list) else [])

    y_pred_from_model = df_pred_['Сопутствующие товары'].values

    return y_pred_from_model

# %%
df_train, df_test = prepare_data(df)
# Out:
# 100%|██████████| 200000/200000 [00:25<00:00, 7896.92it/s]
# <ipython-input-4-d381978901cd>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['Другая продукция в контрактах'] = (

# %%
df_pred = pd.read_csv('result_similars.csv', index_col=0)
y_true = df_test['Другая продукция в контрактах'].values
#y_pred_from_baseline = get_pred_from_baseline(df_train, df_test)
y_pred_from_model = get_pred_from_model(df_test, df_pred)
metrics(y_true, y_pred_from_model)
# Out:
# (0.005926794653465269, 0.27905)

# %%
# Out:
# /var/folders/_5/bdhj5kd96qb1ll895tjts0sm0000gq/T/ipykernel_72813/435196024.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['Кол-во заключенных контрактов'] = df_train['Кол-во заключенных контрактов'].fillna(0)
# /var/folders/_5/bdhj5kd96qb1ll895tjts0sm0000gq/T/ipykernel_72813/435196024.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['tuple'] = df_train.apply(lambda row: (row['Идентификатор СТЕ'], row['Кол-во заключенных контрактов']), axis=1)

# %%
metrics(y_true, y_pred_from_baseline)
# Out:
# (0.006726597512868572, 0.34175)

# %%
# Out:
# (0.0050806150189221175, 0.29005)

# %% [markdown]
# -------

# %%
df_test.index[5]
# Out:
# 1228720

# %%
df['Идентификатор СТЕ'] = df['Идентификатор СТЕ'].astype(str)

# %%
df.set_index('Идентификатор СТЕ').loc[str(df_test.index[5])][['Наименование СТЕ', 'Категория']].values
# Out:
# array(['Блокнот на спирали А5 60 листов 40 штук в упаковке', 'Блокнот'],
#       dtype=object)

# %%
[x['OtherSkuName'] for x in df.set_index('Идентификатор СТЕ').loc[str(df_test.index[5])]['Другая продукция в контрактах']]
# Out:
# ['ArtSpace Альбом для акварели 30 листов вид 1',
#  'Avery Zweckform Этикетки для кухни Living 47,5 х 73 мм',
#  'Berlingo Корректирующая жидкость 20 мл',
#  'Berlingo Папка-скоросшиватель цвет фиолетовый 20 шт',
#  'Berlingo Ручка шариковая Mega Soft синяя',
#  'Berlingo Текстовыделитель цвет розовый',
#  'BIC Увлажнитель для пальцев гелевый 1314670',
#  'Brauberg Нож канцелярский 18 мм 235402',
#  'Centropen Набор перманентных маркеров 4 цвета',
#  'Colop Сменная штемпельная подушка E/R45 цвет синий',
#  'Crown Ручка гелевая HJR-500R зеленая',
#  'Faber-Castell Текстовыделитель цвет зеленый',
#  'Hatber Тетрадь Mono Colour 96 листов в клетку цвет синий',
#  'Index Ежедневник Altero недатированный 168 листов',
#  'Kroyter Альбом для рисования акварелью 40 листов',
#  "Maped Карандаш чернографитный Black Pep's",
#  'Maped Нож канцелярский цвет голубой 9 мм',
#  'Milan Ластик 1012',
#  'Milan Ластик 118 цвет белый',
#  'Milan Ластик Extra Soft 5020 прямоугольный',
#  'Milan Ластик Nata 648 прямоугольный',
#  'MunHwa Ручка шариковая MC Gold синяя 1088418',
#  'Office Force Stationery Дырокол Heavy Duty 65 листов 2 отверстия цвет черный',
#  'Office Force Stationery Точилка механическая пластиковая цвет черный',
#  'OfficeSpace Зажим для бумаг 32 мм 12 шт',
#  'Oxford Тетрадь International Easybook 80 листов в клетку формат А4+',
#  'Pilot Ручка шариковая BPRK-10M-L цвет чернил синий',
#  'Staedtler Линейка цвет прозрачный 40 см',
#  'Unibob Клейкая лента 50 мм х 66 м цвет прозрачный',
#  'Альбом для рисования акварелью "Kroyter", 20 листов, формат А4',
#  'Альбом для черчения 40л,склей,180гр,А4,тиснение фольгой,01536',
#  'Антистеплер',
#  'Антистеплер',
#  'Антистеплер  черный с фиксатором',
#  'Антистеплер 6412 для скоб №10,24/6,26/6, с фикс., черный',
#  'Антистеплер Attache Economy N10, 24/6, 26/6',
#  'Антистеплер ATTACHE для скоб №10, 24/6,26/6, с фикс., черный',
#  'Антистеплер SAX 700 для скоб №24/6,26/6, с фикс., синий',
#  'Антистеплер антистеплер Attache Happy, цвета в ассортименте',
#  'Антистеплер красный Attache Economy ',
#  'Антистеплер черный Attache Economy',
#  'Апплика Цветной картон фольгинированный Замок 5 листов',
#  'Батарейки Promega пальчиковые АA LR6 (10 штук в упаковке)',
#  'Бейдж Attache Economy горизонтальный 90х55 мм булавка/зажим (50 штук в упаковке)',
#  'Бейдж вертикальный 54х85, зеленый, T-732V',
#  'Бейдж горизонтальный 105х74, зеленый, T-733H',
#  'Бизнес-тетрадь 100л,кл,А5,LightBook,спираль,обл.синий,блок белый 70г/м',
#  'Бизнес-тетрадь 120л,кл,А4,Орхидея,гребень,глянц.ламинир(120-8106)',
#  'Бизнес-тетрадь 140л,кл,А5,SPIRAL BOOK Салатовый,евросп,обл.пл,раздел.84108',
#  'Бизнес-тетрадь A4,96л,клетка,спираль Пейзажи VK в ассорт 046679',
#  'Бизнес-тетрадь Attache Клэр А5, 120л, клетка, кожзам, красная 11.02',
#  'Бизнес-тетрадь Kroyter Офис А5 80 листов разноцветная в клетку на скрепке (145х206 мм)',
#  'Бизнес-тетрадь Leitz WOW, А4, 80л, тверд. переплет, кл., бирюзовый 46261051',
#  'Бизнес-тетрадь WAVES А5 100л. ATTACHE клет,спир,пласт,заклад,цв.зеленый',
#  'Бизнес-тетрадь Wisdom 7,А6,120л,100х140, 3 разд,рез под руч,клет,рад2,0007',
#  'Бизнес-тетрадь А4,140 л,пласт обл, с разд,спир,ATTACHE FANTASY,салат',
#  'Бизнес-тетрадь А5,120 л,спираль,клетка Office Creative',
#  'Бизнес-тетрадь А5,140 л,пласт обл, с разд,спир,ATTACHE FANTASY,голуб',
#  'Бизнес-тетрадь Аttache Сoncept А4/120л,тв. переплет на спирали,кл,синий',
#  'Бизнес-тетрадь Канц-Эксмо A4 48 листов фиолетовая в клетку на скрепке (201x274 мм, артикул производителя Т4484576/9)',
#  'Бизнес-тетрадь Комус Feeling черный А4 80л с пласт.обл, клетка',
#  'Бизнес-тетрадь Комус Русская серия синий А4 96л.плас.обл.клетка, евр',
#  'Бизнес-тетрадь Проф-пресс Город на острове А5 64 листа комбинированная на сшивке (205х145 мм)',
#  'Бизнес-тетрадь Тетрапром Колористика A4 96 листов разноцветная в клетку на спирали (202x270 мм)',
#  'Бирки для ключей 10 шт/уп, зеленая',
#  'Бирки для ключей 10 шт/уп, красная',
#  'Бирки для ключей 10шт/уп, синяя',
#  'Бланк Личная карточка работника форма Т-2 офсет А4 - в сложенном виде (297x420 мм, 50 листов, в термоусадочной пленке) арт.66990',
#  'Блок бумаги для флипчартов белый 67,5х98 10 лист. 80гр.',
#  'Блок бумаги для флипчартов клетка 67,5х98 50 лист. 80гр.',
#  'Блок для записей Attache 90x90x90 мм белый (плотность 60 г/кв.м)',
#  'Блок для записей Attache 90x90x90 мм белый (плотность 80-100 г/кв.м)',
#  'Блок для записей Attache Economy 100x100x100 мм белый (плотность 65 г/кв.м)',
#  'Блок для записей Attache Economy запасной 9х9х5 белый',
#  'Блок для записей Attache Economy запасной 9х9х9 цветной',
#  'Блок для записей Attache Economy на склейке 9х9х9 белый',
#  'Блок для записей ATTACHE запасной 9х9х5 белый блок',
#  'Блок для записей ATTACHE запасной 9х9х5 цветной блок',
#  'Блок для записей ATTACHE запасной 9х9х9 белый блок',
#  'Блок для записей ATTACHE запасной 9х9х9 белый блок, арт.32389',
#  'Блок для записей ATTACHE на склейке 9х9х5 белый блок',
#  'Блок для записей ATTACHE ЭКОНОМ запасной 9х9х9 белый',
#  'Блок для записей ATTACHE ЭКОНОМ запасной 9х9х9 цветной',
#  'Блок для записей ATTACHE ЭКОНОМ на склейке 9х9х9 белый',
#  'Блок для записей BRAUBERG непроклеенный, куб 9х9х9 см, цветной',
#  'Блок для записей в подставке ATTACHE 9х9х9 белый блок',
#  'Блок для записей в подставке ATTACHE 9х9х9 белый блок',
#  'Блок для записей в подставке ATTACHE Fantasy 9х9х5 розовый белый блок',
#  'Блок для записей в подставке ATTACHE Fantasy 9х9х5 салатовый белый блок',
#  'Блок для записей в подставке КОМУС\xa0 9х9х9 белый блок',
#  'Блок для записей КОМУС запасной 9х9х5 белый блок',
#  'Блок для записей КОМУС запасной 9х9х9 белый блок',
#  'Блок для записей КОМУС на склейке 9х9х5 белый блок',
#  'Блок для записей КОМУС на склейке 9х9х9 белый блок',
#  'Блок для записей КОМУС на склейке 9х9х9 цветной блок',
#  'Блок для записи',
#  'Блок для записи Berlingo "Premium", 9*9*9, пластиковый бокс, белый, 100% белизна',
#  'Блок для записи с клеевым краем Lamark 38*51',
#  'Блок самоклеящийся (стикер) POST-IT Basic, 76х76 мм, 100 л., голубой',
#  'Блок самоклеящийся (стикер) POST-IT Super Sticky, 76х76 мм, 90 л., неоновый розовый',
#  'Блок самоклеящийся (стикер), STAFF, 76х76 мм, 100 л., желтый',
#  'Блок самоклеящийся (стикеры) STAFF, ПАСТЕЛЬНЫЙ, 38х51 мм, 100 листов, НАБОР 12 штук, 3 цвета, 129346',
#  'Блок-кубик Attache Selection куб 76х76, желтый неон 400 л',
#  'Блок-кубик Attache Selection куб 76х76, радуга 400 л',
#  'Блок-кубик Attache Selection куб 76х76, радуга 400 л',
#  'Блок-кубик Attache Selection куб 76х76, фреш 400 л',
#  'Блок-кубик Attache Selection куб 76х76, фреш 400 л',
#  'Блок-кубик Attache Selection миникуб 51х51, клубничный микс 250 л',
#  'Блок-кубик Attache Selection миникуб 51х51, радуга 250 л',
#  'Блок-кубик Attache Selection миникуб 51х51, радуга 250 л',
#  'Блок-кубик Attache Selection миникуб 51х51, фреш 250 л',
#  'Блок-кубик Attache Selection с клеев. краем 38х51, неон, 4 цвета 50х4',
#  'Блок-кубик Attache Selection с клеев. краем 76х51, неон, голубой 100л',
#  'Блок-кубик Attache Selection с клеев. краем 76х51, неон, зеленый 100л',
#  'Блок-кубик Attache Selection с клеев. краем 76х51, неон, фиолет. 100л',
#  'Блок-кубик Attache Selection с клеев. краем 76х76, неон, пурпур. 100л',
#  'Блок-кубик ATTACHE с клеев.краем 51х51 голубой 100л.',
#  'Блок-кубик ATTACHE с клеев.краем 51х51 розовый 100л.',
#  'Блок-кубик ATTACHE с клеев.краем 51х51 салатовый 100л.',
#  'Блок-кубик ATTACHE с клеев.краем 76х51 голубой 100л.',
#  'Блок-кубик ATTACHE с клеев.краем 76х51 розовый 100л.',
#  'Блок-кубик ATTACHE с клеев.краем 76х51 салатовый 100л.',
#  'Блок-кубик ATTACHE с клеев.краем 76х76 розовый 100л.',
#  'Блок-кубик ATTACHE с клеев.краем 76х76 салатовый 100л.',
#  'Блок-кубик ATTACHE с клеевым краем 76х76 голубой 100л. арт.356199',
#  'Блок-кубик ATTACHE с клеевым краем 76х76 желтый 100л.',
#  'Блок-кубик ATTACHE ЭКОНОМ запасной 9х9х4,5 белый',
#  "Блок-кубик Kores бум.для зам. 100х75 желтая 100л. '46100",
#  "Блок-кубик Kores бум.для зам. 75х75 желтая 100л. '46075",
#  'Блок-кубик Post-it 653 38х51 желтая 3бл.х100л',
#  'Блок-кубик Post-it 653-TF 38х51 Тепл.неон.радуга,12бл.',
#  'Блок-кубик Post-it 6812 38х51, 3бл.(цветн.)',
#  'Блок-кубик Post-it Basic 653R-BY, канареечный желт 38х51мм 12блх100 л.',
#  'Блок-кубик Post-it Basic 654R-BP, розовые, 76х76 мм, 100 л',
#  'Блок-кубик Post-it Super Sticky 654R-SG, 76х76 зеленый,90л.',
#  'Блок-кубик Post-it Super Sticky 654-S 76х76 желтый,90л',
#  'Блок-кубик Post-it куб 2028-ONP 76х76 лето плюс 500 л.',
#  'Блок-кубик Post-it куб 2028-OPB 76х76 зима 400 л.',
#  'Блок-кубик КОМУС с клеев.краем 76х76 желтый 100л..',
#  'Блокнот 80л А5ф жесткая подложка клетка на гребне серия INSIDE',
#  'Блокнот Attache Selection Llamas A6 80 листов белый в клетку на спирали (101x145 мм)',
#  'Блокнот Hatber Metallic А6 80 листов бордовый в клетку на спирали (110х155 мм)',
#  'Блокнот А4,60л,клетка,метал.гребень,цв.обложка Стильный Офис 2933',
#  'Блокнот А4,80л,клетка,метал.гребень,цв.обложка Стильный Офис 2752',
#  'Блокнот А5, 60 л., гребень, жесткая подложка, клетка, STAFF, 4 вида, 146х206 мм',
#  'Блокнот А7,пласт обл,80л, ATTACHE FANTASY,голуб',
#  'Блокнот ГРАФО спираль А6 50л. клетка',
#  'Блокнот детский 48л,кл,А7,3-х цв.бл,клей,Автопанорама(48Б7B1к_004769) в асс',
#  'Блокнот Комус на спирали, синий, А6, 80л, клетка',
#  'Блокнот на спирали А4 60л. ATTACHE, синий, блок 60г, обложка 215г',
#  'Блокнот на спирали А4 80л. ATTACHE клетка, однот.пласт обл.',
#  'Блокнот на спирали А5 80л. ATTACHE клетка, однот.пласт обл.',
#  'Блокнот на спирали А6 60л. ATTACHE, синий, блок 60г, обложка 215г',
#  'Блокнот Полином Стильный офис А5 60 листов в ассортименте в клетку на спирали (145x203 мм)',
#  'Блокнот СОБАКИ А6 40л на гребне в ассорт 3-40-297 Д',
#  'Бокс для бумаги 9х9х5 ',
#  'Булавки Attache Economy металлические 24 мм (500 штук в упаковке)',
#  'Булавки английские BLITZ, набор 125 шт., размер 0-4, никелированные, блистер',
#  'Булавки металлич. 30 мм ATTACHE Б35, 500шт/уп., с подвесом',
#  'Булавки офисные STAFF, 28 мм, 150 шт., в картонной коробке',
#  'Бумага Albeo Z80-24-6 InkJet Paper 610мм 45,7м 80гр Мультипак',
#  'Бумага COLOR COPY SILK, мелованная, матовая, А4, 170 г/м2, 250 л., для полноцветной лазерной печати, А++, Австрия, 138% (CIE)',
#  'Бумага IQ COLOR Pastell Mixed, А4, 80 г/м, 5цв. по 50л., 250л./пач.',
#  'Бумага IQ color, А4',
#  'Бумага IQ Economy A4 (146% CIE, 80г/м, 500л)',
#  'Бумага акварельная "Kroyter", формат А3, 200 листов',
#  'Бумага для заметок 76*76 400л.',
#  'Бумага для офисной техники IQ Allround (А4, 80 г/кв.м, белизна 162% CIE, 500 листов)',
#  'Бумага для офисной техники SvetoCopy',
#  'Бумага для офисной техники SvetoCopy  (А3, 80г/м2, белизна 146%, 500 листов)',
#  'Бумага для офисной техники SvetoCopy (A4, марка C, 80 г/кв.м, 500 листов)',
#  'Бумага для офисной техники SvetoCopy (A4, марка C, 80 г/кв.м, 500 листов)',
#  'Бумага для офисной техники SvetoCopy (А3, марка C, 80 г/кв.м, 500 листов)',
#  'Бумага для офисной техники белая SvetoCopy А3',
#  'Бумага для ОфТех Ballet Premier (А3,80 г/кв.м,белизна 161% CIE,500листов)',
#  'Бумага для ОфТех Navigator Universal (А4, 80 г/м, 169 % CIE) пачка 500 л.',
#  'Бумага для ОфТех SVETO COPY (А4,80г,146%CIE) пачка 500л.',
#  'Бумага для творчества креповая,50х250см,32г/м2,красная,CR25004',
#  'Бумага для творчества металлизирован.для оригами 6л.6цв.,20х20см.',
#  'Бумага для цв.лазер.печ. Color Copy (А4,200г,161CIE%) 250л/пач,5пач/кор',
#  'Бумага для эскизов "Палаццо", 20 листов, формат А4',
#  'Бумага офисная KYM LUX BUSINESS, А4, 70 г/м2, 500 л., марка В, Финляндия, белизна 164%',
#  'Бумага офисная А3, класс "В+", IQ ALLROUND, 80 г/м2, 500 л., Сыктывкар, белизна 162% (CIE)',
#  'Бумага туалетная Luscan Professional 2сл бел втор втул 21,88м 175л 24рул/уп',
#  'Бумага цветная IQ COLOR (А4,160г,GN27-светло-зеленый) пачка 250л.',
#  'Бумага цветная IQ COLOR (А4,160г,OBL70-голубой лед) пачка 250л.',
#  'Бумага цветная IQ COLOR (А4,160г,YE23-желтый) пачка 250л.',
#  'Бумага цветная IQ COLOR (А4,80г,LA12-бледно-лиловый) пачка 500л.',
#  'Бумага цветная А4,8л,8цв, тонированная, С2767-01/02',
#  'Бумага цветная Комус Color (красный интенсив), 80г, А4, 100 л.',
#  'Бумага цветная Комус Color (красный интенсив), 80г, А4, 500 л.',
#  'Бумага широкоформатная MEGA Engineer,InkJet,90г,24 /610ммх45м,д50,8мм.',
#  'Бумага широкоформатная MEGA Engineer,InkJet,90г,36 /914ммх45м,д50,8мм.',
#  'Бумага широкоформатная ProMEGA engineer InkJet 80г 914ммх45м 50,8мм',
#  'Бух брошюры Вкладыш к трудовой книжке (10штук в упаковке)',
#  'Бух брошюры Книга учета движения трудовых книжек и вклад. в них',
#  'Бух книги амбарная в клетку 96л.обл.плотн.картон г/б',
#  'Бух книги амбарная в линейку 96л.обл.плотн.картон г/б',
#  'Бух книги журнал приема-сдачи ключей от служеб.помещ. А4, 50л.',
#  'Бух книги Журнал регистрации вводного инструктажа, 32л.',
#  'Бух книги Журнал регистрации исходящих документов,офсет,скрепка48 л.',
#  'Бух книги отзывов и предложений в тв.переплете A5 96л(бумвин.с тесн)',
#  'Бух книги учета 96 листов в клетку офсет, ATTACHE 26586',
#  'Бух книги учёта 96л в линейку обл. однот.цв.картон Альт',
#  'Бух книги учета Attache 96л. в клетку офсет обл.плотн. картон',
#  'Бух книги учета_144л. в линейку офсет, обл.бумвинил ATTACHE',
#  'Бюрократ Папка-уголок цвет желтый',
#  'Бюрократ Папка-уголок цвет красный',
#  'Бюрократ Папка-уголок цвет синий',
#  'Ватман А1 (610 х 860 мм), 1 лист, плотность 200 г/м2, ГОЗНАК С-Пб, упаковка по 100 листов, водяной знак',
#  'Вертикальный накопитель 115мм Attache OPEN SPACE прозрачный синий',
#  'Вертикальный накопитель ATTACHE 70мм (65) черный 4шт/упк',
#  'Вертикальный накопитель Attache 70мм прозрачный',
#  'Вертикальный накопитель Attache 70мм прозрачный',
#  'Вертикальный накопитель Attache 70мм серый',
#  'Вертикальный накопитель Attache 85мм прозрачный 4шт/упк',
#  'Вертикальный накопитель Attache 85мм черный 2 шт/упк',
#  'Вертикальный накопитель Attache 90мм прозрачный зеленый',
#  'Вертикальный накопитель Attache 90мм серый',
#  'Вертикальный накопитель ATTACHE 95мм черный 2 шт/упк',
#  'Вертикальный накопитель ATTACHE 95мм Яркий Офис тонир Вишня',
#  'Вертикальный накопитель ATTACHE 95мм Яркий Офис тонир Слива',
#  'Вертикальный накопитель Attache City 90мм тонированный',
#  'Вертикальный накопитель Attache City 90мм черный',
#  'Вертикальный накопитель Attache Economy 70мм Респект черный',
#  'Вертикальный накопитель Attache Selection Flamingo пластиковый прозрачный голубой ширина 110 мм',
#  'Вертикальный накопитель Attache сборный 4 отделения по 40мм+орган. черн',
#  'Вертикальный накопитель Attache сборный 6 отделений 240мм черный',
#  "Вертикальный накопитель Leitz Plus Jumbo 70мм/3 отд. черный '52390095",
#  'Вертикальный накопитель Leitz WOW 70мм двухцветный черный',
#  'Вертикальный накопитель Комус Русская серия 85мм синий прозрачный',
#  'Вертикальный накопитель; Attache; 95,00000 мм; зеленый; Количество отделений 1',
#  'Вешалка-плечики, размер 48-50, деревянная, анатомическая, перекладина, цвет вишня, BRABIX "Люкс"',
#  'Визитки',
#  'Грамота',
#  'Грамота с тиснением фольга',
#  'Грамота школьная',
#  'Грифель запасной PILOT PPL-5, HB, 0,5 мм, 12 штук',
#  'Губка для мытья посуды Губка Luscan для посуды Мини',
#  'Губка-стиратель для маркерных досок Attache Economy 7x4x1.8cм, 2шт/уп',
#  'Губка-стиратель для маркерных досок Attache Economy Губка резиновая',
#  'Губка-стиратель для маркерных досок Губка с пластиковым держателем атташе',
#  'Губка-стиратель для маркерных досок Губка Смайл',
#  'Датер автоматический мини S120 Bank шрифт 3,8мм месяц цифр. (аналог 4810B) Col  арт.218 993',
#  'Датер автоматический мини S120 шрифт 3,8мм месяц букв.(аналог 4810)Colop',
#  'Датер автоматический пласт. S220Bank шрифт 4мм месяц цифр.(аналог 4820B)Col',
#  'Двухсторонняя клейкая лента на полипропиленовой основе STAYER, 50мм х 25м',
#  'Держатель для бейджа Комус с рулеткой цвет металик (без бейджа) 1шт',
#  'Держатель-рулетка для бейджей BRAUBERG, 70 см, петелька, карабин, синий, в блистере',
#  'Диспенсер для клейкой ленты канцелярской 3M H-127 прозрачн.для Scotch до19м',
#  'Доска магнитно-маркерная 90х120 Attache Economy лак',
#  'Доска пробковая 60х90 деревян. рама Комус',
#  'Доска-флипчарт BRAUBERG магнитно-маркерная, стандарт, 70?100 см, передвижная',
#  'Дырокол Attache Economy до 20 листов синий с линейкой',
#  'Дырокол Attache Economy до 20 листов, с линейкой, цвет черный',
#  'Дырокол Attache Selechion до 20 листов, цвет белый',
#  'Дырокол Attache до 30 листов, с линейкой, цвет черный',
#  'Дырокол Attache до 35 листов синий с блокиратором',
#  'Дырокол Attache до 40 листов, с линейкой, цвет синий',
#  'Дырокол Attache до 40 листов, с линейкой, цвет черный',
#  'Дырокол BRAUBERG "Endeavor", металлический, большой, на 40 листов, ассорти (синий, черный)',
#  'Дырокол Kw-trio для люверсов на 30 л. серебристый',
#  'Дырокол Kw-trio для люверсов на 30 л. серебристый',
#  'Дырокол SAX 406 до 30л., металл, с лин., синий, Австрия-Венгрия',
#  'Дырокол SAX 506 до 40л., металл, с лин., красный, Австрия-Венгрия',
#  'Дырокол SAX 506 до 40л., металл, с лин., синий, Австрия-Венгрия',
#  'Дырокол Люверсы 250 шт./уп Kw-Trio, диаметр= 4,8, золотистые',
#  'Дырокол люверсы 250 шт./уп, диаметр= 4,8, золотистые',
#  'Дырокол мощный до 150 листов',
#  'Ежедневник А5  METROPOL  (СИНИЙ)3-491/01',
#  'Ежедневник А5 MEGAPOLIS SOFT (БОРДО) 3-470/05',
#  'Ежедневник А5 MEGAPOLIS SOFT (СИНИЙ)3-470/03',
#  'Ежедневник датированный 2021 А5 (138х213 мм) BRAUBERG «Favorite», кожзам, черный, 111369',
#  'Ежедневник датированный 2021 год Attache Economy бумвинил A5 160 листов синий (147x206 мм)']

# %%
df.set_index('Идентификатор СТЕ').loc[y_pred_baseline[5]]['Наименование СТЕ']
# Out:
# Идентификатор СТЕ
# 1252158     Бумага для флипчартов Блок бумаги для флипчарт...
# 1209261     Блокнот для флипчарта BRAUBERG, 50 листов, чис...
# 1223616     Блокнот А5, 80 л., гребень, мелованный картон ...
# 1226194     Бумага для флипчартов Блок бумаги для флипчарт...
# 23454650    Тетрадь 96л., А4, клетка OfficeSpace, бумвинил...
# 22264995    Бизнес-тетрадь Attache Selection Fluid A4 96 л...
# 1209258     Блокнот для флипчарта BRAUBERG, 20 листов, кле...
# 16892261    Блокнот Полином Природа А5 80 листов разноцвет...
# 22993304    Блокнот А5 (146?205 мм), 80 л., гребень, карто...
# 28533123    Бумага для флипчартов 67.5х98 см белая 20 лист...
# 1209188     Блокноты для флипчарта ОФИСМАГ, комплект 5 шт....
# 1223642     Блокнот А5, 80 л., гребень, жесткая подложка, ...
# 1208848     Блокноты для флипчарта BRAUBERG, комплект 5 шт...
# 1223615     Блокнот А4, 80 л., спираль, жесткая подложка, ...
# 1208845     Блокнот для флипчарта "2х3" ("Дважды три", Пол...
# 1230383     Бумага для флипчартов Блок бумаги для флипчарт...
# 34233392    Блокнот А5 (146х205 мм), 60 л., гребень, карто...
# 1348466                                            Блокнот А5
# 22265434    Блокнот Attache Selection Fluid A6 80 листов ф...
# 1209260     Блокнот для флипчарта BRAUBERG, 50 листов, кле...
# Name: Наименование СТЕ, dtype: object

# %%
df.set_index('Идентификатор СТЕ').loc[y_pred_good[5]]['Наименование СТЕ']
# Out:
# Идентификатор СТЕ
# 28533123    Бумага для флипчартов 67.5х98 см белая 20 лист...
# 1236648     Блокнот на спирали А5 60л. синий картон д/лог....
# 1228731     Блокнот на спирали А4 80л. ATTACHE клетка, одн...
# 1228768          Блокнот А5 60л. ULTIMATE BASICS, ACTIVE BOOK
# 1252718       Блокнот А6,пласт обл,80л, ATTACHE FANTASY,салат
# 20807500    Булавки Attache Economy металлические 24 мм (5...
# 1232159     Булавки металлич. 30 мм ATTACHE Б35, 500шт/уп....
# 1248232     Булавки металлич. 30 мм ATTACHE Б35, 500шт/уп....
# 1232348                                Бокс для бумаги 9х9х9
# 1232347                                Бокс для бумаги 9х9х5
# 20290603    Булавки для пробковых досок Globus (30 мм, 150...
# 23368841    Булавки для пробковых досок Globus (30 мм, 100...
# Name: Наименование СТЕ, dtype: object
